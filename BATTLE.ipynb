# %% [markdown]
# # Introduction and Business Problem
# ## Introduction:
#
# The city of Hoboken, NJ is relatively small at ~1 square mile but it is packed with restaurants, night life and amazing people. For people that are new to Hoboken, despite its small geographic size, it can be daunting to figure out what restaurants are worth going to and where they are. For people that used to live in Hoboken or are visiting Hoboken, how do you know what the best places are to get something to eat?
# # A description of the problem and a discussion of the background
# ### Business Problem:
#
# For this project, I am going to put on my entrepreneur hat and create a simple guide on where to eat based on Foursquare likes, restaurant category and geographic location data for restaurants in Hoboken. I will then cluster these restaurants based on their similarities so that a user can easily determine what type of restaurants are best to eat at based on Foursquare user feedback.
# Data Required
# For this assignment, I will be utilizing the Foursquare API to pull the following location data on restaurants in Hoboken, NJ:
#
# Venue Name
# Venue ID
# Venue Location
# Venue Category
# Count of Likes
# Data Acquisition Approach
# To acquire the data mentioned above, I will need to do the following:
#
# Get geolocator lat and long coordinates for Hoboken, NJ
# Use Foursquare API to get a list of all venues in Hoboken
# Get venue name, venue ID, location, category, and likes
# Algorithm Used
# I will take the gathered data (see above in Data Acquisition Approach and Data Required sections) and will create a k-means clustering algorithm that groups restaurants into 4-5 clusters so that people looking to eat in Hoboken can easily see which restaurants are the best to eat at, what cuisine is available and where in Hoboken they can look to eat.
#
# Data Prep and Pull
# We will import our necessary packages and start pulling our data for data prep and usage.
#
# # A description of the data and how it will be used to solve the problem
#  the data will be used to calculate the locay

# %%
import numpy as np # library to handle data in a vectorized manner

import pandas as pd # library for data analsysis
pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', None)

import json # library to handle JSON files

# !conda install -c conda-forge geopy --yes # uncomment this line if you haven't completed the Foursquare API lab
from geopy.geocoders import Nominatim # convert an address into latitude and longitude values

import requests # library to handle requests
from pandas.io.json import json_normalize # tranform JSON file into a pandas dataframe

# Matplotlib and associated plotting modules
import matplotlib.cm as cm
import matplotlib.colors as colors

# import k-means from clustering stage
from sklearn.cluster import KMeans

# !conda install -c conda-forge folium=0.5.0 --yes # uncomment this line if you haven't completed the Foursquare API lab
import folium # map rendering library

#import beautiful soup
from urllib.request import urlopen
from bs4 import BeautifulSoup


print('Libraries imported.')
# Out:
# Solving environment: done
#
# # All requested packages already installed.
#
# Solving environment: done
#
# # All requested packages already installed.
#
# Libraries imported.

# %%
address = 'Hoboken, New Jersey'

geolocator = Nominatim()
location = geolocator.geocode(address)
latitude = location.latitude
longitude = location.longitude
print('The geograpical coordinate of Hoboken are {}, {}.'.format(latitude, longitude))
# Out:
# /opt/conda/envs/Python36/lib/python3.6/site-packages/ipykernel/__main__.py:3: DeprecationWarning: Using Nominatim with the default "geopy/1.20.0" `user_agent` is strongly discouraged, as it violates Nominatim's ToS https://operations.osmfoundation.org/policies/nominatim/ and may possibly cause 403 and 429 HTTP errors. Please specify a custom `user_agent` with `Nominatim(user_agent="my-application")` or by overriding the default `user_agent`: `geopy.geocoders.options.default_user_agent = "my-application"`. In geopy 2.0 this will become an exception.
#   app.launch_new_instance()
# The geograpical coordinate of Hoboken are 40.7433066, -74.0323752.

# %%
CLIENT_ID = '' # your Foursquare ID
CLIENT_SECRET = '' # your Foursquare Secret
VERSION = '20190909' # Foursquare API version

print('Your credentails:')
print('CLIENT_ID: ' + CLIENT_ID)
print('CLIENT_SECRET:' + CLIENT_SECRET)
# Out:
# Your credentails:
# CLIENT_ID:
# CLIENT_SECRET:

# %%
LIMIT = 100 # limit of number of venues returned by Foursquare API
radius = 500 # define radius

# create URL
url = 'https://api.foursquare.com/v2/venues/explore?&client_id={}&client_secret={}&v={}&ll={},{}&radius={}&limit={}'.format(
    CLIENT_ID, 
    CLIENT_SECRET, 
    VERSION, 
    latitude, 
    longitude, 
    radius, 
    LIMIT)
url
# Out:
# 'https://api.foursquare.com/v2/venues/explore?&client_id=STF5SBN4C1FOSL0NNVXVSDWPQEY5RMNBOL02C5TFP0RYO1W3&client_secret=O23W1CW0LJ3L3GT2FHPZPOZ4XECGQRVBUDTYB02R0G1LCONZ&v=20190909&ll=40.7433066,-74.0323752&radius=500&limit=100'

# %%
results = requests.get(url).json()
results
# Out:
# {'meta': {'code': 200, 'requestId': '5d7696c4446ea60037d15f50'},
#  'response': {'suggestedFilters': {'header': 'Tap to show:',
#    'filters': [{'name': 'Open now', 'key': 'openNow'},
#     {'name': '$-$$$$', 'key': 'price'}]},
#   'headerLocation': 'Hoboken',
#   'headerFullLocation': 'Hoboken',
#   'headerLocationGranularity': 'city',
#   'totalResults': 114,
#   'suggestedBounds': {'ne': {'lat': 40.7478066045, 'lng': -74.0264467971303},
#    'sw': {'lat': 40.738806595499995, 'lng': -74.0383036028697}},
#   'groups': [{'type': 'Recommended Places',
#     'name': 'recommended',
#     'items': [{'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4cdf46dadb125481eb4236ce',
#        'name': 'Work It Out-A Fitness Boutique',
#        'location': {'address': '603 Willow Ave',
#         'lat': 40.744356367758414,
#         'lng': -74.03256658205021,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 40.744356367758414,
#           'lng': -74.03256658205021}],
#         'distance': 117,
#         'postalCode': '07030',
#         'cc': 'US',
#         'city': 'Hoboken',
#         'state': 'NJ',
#         'country': 'United States',
#         'formattedAddress': ['603 Willow Ave',
#          'Hoboken, NJ 07030',
#          'United States']},
#        'categories': [{'id': '4bf58dd8d48988d175941735',
#          'name': 'Gym / Fitness Center',
#          'pluralName': 'Gyms or Fitness Centers',
#          'shortName': 'Gym / Fitness',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/gym_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4cdf46dadb125481eb4236ce-0'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '49e9e49df964a5200a661fe3',
#        'name': 'Church Square Park',
#        'location': {'address': '401 Willow Ave.',
#         'crossStreet': '4th St.',
#         'lat': 40.74215230390258,
#         'lng': -74.03223037719727,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 40.74215230390258,
#           'lng': -74.03223037719727}],
#         'distance': 129,
#         'postalCode': '07030',
#         'cc': 'US',
#         'city': 'Hoboken',
#         'state': 'NJ',
#         'country': 'United States',
#         'formattedAddress': ['401 Willow Ave. (4th St.)',
#          'Hoboken, NJ 07030',
#          'United States']},
#        'categories': [{'id': '4bf58dd8d48988d163941735',
#          'name': 'Park',
#          'pluralName': 'Parks',
#          'shortName': 'Park',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/parks_outdoors/park_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-49e9e49df964a5200a661fe3-1'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '45e9482df964a52075431fe3',
#        'name': "Onieal's Restaurant & Bar",
#        'location': {'address': '343 Park Ave',
#         'crossStreet': 'btwn 3rd St & 4th St',
#         'lat': 40.741608,
#         'lng': -74.032304,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 40.741608,
#           'lng': -74.032304}],
#         'distance': 189,
#         'postalCode': '07030',
#         'cc': 'US',
#         'city': 'Hoboken',
#         'state': 'NJ',
#         'country': 'United States',
#         'formattedAddress': ['343 Park Ave (btwn 3rd St & 4th St)',
#          'Hoboken, NJ 07030',
#          'United States']},
#        'categories': [{'id': '4bf58dd8d48988d11b941735',
#          'name': 'Pub',
#          'pluralName': 'Pubs',
#          'shortName': 'Pub',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/nightlife/pub_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-45e9482df964a52075431fe3-2'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4a4e740ff964a5207bae1fe3',
#        'name': 'Sweet',
#        'location': {'address': '343 Garden St',
#         'crossStreet': '4th St',
#         'lat': 40.741623250618346,
#         'lng': -74.03152338274533,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 40.741623250618346,
#           'lng': -74.03152338274533}],
#         'distance': 200,
#         'postalCode': '07030',
#         'cc': 'US',
#         'city': 'Hoboken',
#         'state': 'NJ',
#         'country': 'United States',
#         'formattedAddress': ['343 Garden St (4th St)',
#          'Hoboken, NJ 07030',
#          'United States']},
#        'categories': [{'id': '4bf58dd8d48988d16a941735',
#          'name': 'Bakery',
#          'pluralName': 'Bakeries',
#          'shortName': 'Bakery',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/bakery_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4a4e740ff964a5207bae1fe3-3'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '56d3b920498ec4e1c67c0907',
#        'name': 'Grand Vin',
#        'location': {'address': '500 Grand St',
#         'crossStreet': '5th St',
#         'lat': 40.743209219791716,
#         'lng': -74.03509903426071,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 40.743209219791716,
#           'lng': -74.03509903426071}],
#         'distance': 229,
#         'postalCode': '07030',
#         'cc': 'US',
#         'city': 'Hoboken',
#         'state': 'NJ',
#         'country': 'United States',
#         'formattedAddress': ['500 Grand St (5th St)',
#          'Hoboken, NJ 07030',
#          'United States']},
#        'categories': [{'id': '4bf58dd8d48988d11e941735',
#          'name': 'Cocktail Bar',
#          'pluralName': 'Cocktail Bars',
#          'shortName': 'Cocktail',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/nightlife/cocktails_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-56d3b920498ec4e1c67c0907-4'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4b6b0a45f964a520a5ee2be3',
#        'name': 'Hoboken General Store',
#        'location': {'address': '507 Willow Ave.',
#         'crossStreet': '5th St.',
#         'lat': 40.7431479485567,
#         'lng': -74.03302984763806,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 40.7431479485567,
#           'lng': -74.03302984763806}],
#         'distance': 57,
#         'postalCode': '07030',
#         'cc': 'US',
#         'city': 'Hoboken',
#         'state': 'NJ',
#         'country': 'United States',
#         'formattedAddress': ['507 Willow Ave. (5th St.)',
#          'Hoboken, NJ 07030',
#          'United States']},
#        'categories': [{'id': '4bf58dd8d48988d146941735',
#          'name': 'Deli / Bodega',
#          'pluralName': 'Delis / Bodegas',
#          'shortName': 'Deli / Bodega',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/deli_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4b6b0a45f964a520a5ee2be3-5'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '582dfc9565be5809f6a964ed',
#        'name': 'Karma Kafe',
#        'location': {'address': '505 Washington St',
#         'lat': 40.74237277495878,
#         'lng': -74.02937643368226,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 40.74237277495878,
#           'lng': -74.02937643368226}],
#         'distance': 273,
#         'postalCode': '07030',
#         'cc': 'US',
#         'city': 'Hoboken',
#         'state': 'NJ',
#         'country': 'United States',
#         'formattedAddress': ['505 Washington St',
#          'Hoboken, NJ 07030',
#          'United States']},
#        'categories': [{'id': '4bf58dd8d48988d10f941735',
#          'name': 'Indian Restaurant',
#          'pluralName': 'Indian Restaurants',
#          'shortName': 'Indian',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/indian_',
#           'suffix': '.png'},
#          'primary': True}],
#        'delivery': {'id': '261352',
#         'url': 'https://www.grubhub.com/restaurant/karma-kafe-505-washington-st-hoboken/261352?affiliate=1131&utm_source=foursquare-affiliate-network&utm_medium=affiliate&utm_campaign=1131&utm_content=261352',
#         'provider': {'name': 'grubhub',
#          'icon': {'prefix': 'https://fastly.4sqi.net/img/general/cap/',
#           'sizes': [40, 50],
#           'name': '/delivery_provider_grubhub_20180129.png'}}},
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-582dfc9565be5809f6a964ed-6'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '56daf06fcd107605ef3d86ea',
#        'name': "O'Bagel",
#        'location': {'address': '600 Washington St',
#         'crossStreet': 'Sixth Street',
#         'lat': 40.743603269894244,
#         'lng': -74.02917265892027,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 40.743603269894244,
#           'lng': -74.02917265892027}],
#         'distance': 272,
#         'postalCode': '07030',
#         'cc': 'US',
#         'city': 'Hoboken',
#         'state': 'NJ',
#         'country': 'United States',
#         'formattedAddress': ['600 Washington St (Sixth Street)',
#          'Hoboken, NJ 07030',
#          'United States']},
#        'categories': [{'id': '4bf58dd8d48988d179941735',
#          'name': 'Bagel Shop',
#          'pluralName': 'Bagel Shops',
#          'shortName': 'Bagels',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/bagels_',
#           'suffix': '.png'},
#          'primary': True}],
#        'delivery': {'id': '333353',
#         'url': 'https://www.grubhub.com/restaurant/obagel-600-washington-st-hoboken/333353?affiliate=1131&utm_source=foursquare-affiliate-network&utm_medium=affiliate&utm_campaign=1131&utm_content=333353',
#         'provider': {'name': 'grubhub',
#          'icon': {'prefix': 'https://fastly.4sqi.net/img/general/cap/',
#           'sizes': [40, 50],
#           'name': '/delivery_provider_grubhub_20180129.png'}}},
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-56daf06fcd107605ef3d86ea-7'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '57168865498e9517f09fa03d',
#        'name': 'Kung Fu Tea',
#        'location': {'address': '536 Washington St',
#         'lat': 40.74334654884085,
#         'lng': -74.02937873321412,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 40.74334654884085,
#           'lng': -74.02937873321412}],
#         'distance': 252,
#         'postalCode': '07030',
#         'cc': 'US',
#         'city': 'Hoboken',
#         'state': 'NJ',
#         'country': 'United States',
#         'formattedAddress': ['536 Washington St',
#          'Hoboken, NJ 07030',
#          'United States']},
#        'categories': [{'id': '52e81612bcbc57f1066b7a0c',
#          'name': 'Bubble Tea Shop',
#          'pluralName': 'Bubble Tea Shops',
#          'shortName': 'Bubble Tea',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/bubble_',
#           'suffix': '.png'},
#          'primary': True}],
#        'delivery': {'id': '446729',
#         'url': 'https://www.grubhub.com/restaurant/kung-fu-tea-536-washington-st-hoboken/446729?affiliate=1131&utm_source=foursquare-affiliate-network&utm_medium=affiliate&utm_campaign=1131&utm_content=446729',
#         'provider': {'name': 'grubhub',
#          'icon': {'prefix': 'https://fastly.4sqi.net/img/general/cap/',
#           'sizes': [40, 50],
#           'name': '/delivery_provider_grubhub_20180129.png'}}},
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-57168865498e9517f09fa03d-8'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '51f1c7e1498e7425c21efab6',
#        'name': 'Anthropologie',
#        'location': {'address': '412 Washington St',
#         'crossStreet': 'Btw 4th & 5th St.',
#         'lat': 40.74183785229468,
#         'lng': -74.02966221343871,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 40.74183785229468,
#           'lng': -74.02966221343871}],
#         'distance': 281,
#         'postalCode': '07030',
#         'cc': 'US',
#         'city': 'Hoboken',
#         'state': 'NJ',
#         'country': 'United States',
#         'formattedAddress': ['412 Washington St (Btw 4th & 5th St.)',
#          'Hoboken, NJ 07030',
#          'United States']},
#        'categories': [{'id': '4bf58dd8d48988d108951735',
#          'name': "Women's Store",
#          'pluralName': "Women's Stores",
#          'shortName': "Women's Store",
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/apparel_women_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-51f1c7e1498e7425c21efab6-9'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4b660130f964a520ce0d2be3',
#        'name': "Dom's Bakery",
#        'location': {'address': '506 Grand St',
#         'crossStreet': 'btw 5th & 6th St',
#         'lat': 40.743386524526805,
#         'lng': -74.03483595097866,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 40.743386524526805,
#           'lng': -74.03483595097866}],
#         'distance': 207,
#         'postalCode': '07030',
#         'cc': 'US',
#         'city': 'Hoboken',
#         'state': 'NJ',
#         'country': 'United States',
#         'formattedAddress': ['506 Grand St (btw 5th & 6th St)',
#          'Hoboken, NJ 07030',
#          'United States']},
#        'categories': [{'id': '4bf58dd8d48988d16a941735',
#          'name': 'Bakery',
#          'pluralName': 'Bakeries',
#          'shortName': 'Bakery',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/bakery_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4b660130f964a520ce0d2be3-10'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4a1098a2f964a520e3761fe3',
#        'name': "Fiore's Deli",
#        'location': {'address': '414 Adams St',
#         'crossStreet': 'btwn 4th & 5th St',
#         'lat': 40.743018792687366,
#         'lng': -74.03618337907415,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 40.743018792687366,
#           'lng': -74.03618337907415}],
#         'distance': 322,
#         'postalCode': '07030',
#         'cc': 'US',
#         'city': 'Hoboken',
#         'state': 'NJ',
#         'country': 'United States',
#         'formattedAddress': ['414 Adams St (btwn 4th & 5th St)',
#          'Hoboken, NJ 07030',
#          'United States']},
#        'categories': [{'id': '4bf58dd8d48988d146941735',
#          'name': 'Deli / Bodega',
#          'pluralName': 'Delis / Bodegas',
#          'shortName': 'Deli / Bodega',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/deli_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4a1098a2f964a520e3761fe3-11'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4dbc9859f7b1ab37dd636d12',
#        'name': 'Ayame Hibachi & Sushi',
#        'location': {'address': '526 Washington St',
#         'crossStreet': 'at 5th St',
#         'lat': 40.74310466720745,
#         'lng': -74.02921272759819,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 40.74310466720745,
#           'lng': -74.02921272759819}],
#         'distance': 267,
#         'postalCode': '07030',
#         'cc': 'US',
#         'city': 'Hoboken',
#         'state': 'NJ',
#         'country': 'United States',
#         'formattedAddress': ['526 Washington St (at 5th St)',
#          'Hoboken, NJ 07030',
#          'United States']},
#        'categories': [{'id': '4bf58dd8d48988d1d2941735',
#          'name': 'Sushi Restaurant',
#          'pluralName': 'Sushi Restaurants',
#          'shortName': 'Sushi',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/sushi_',
#           'suffix': '.png'},
#          'primary': True}],
#        'delivery': {'id': '296370',
#         'url': 'https://www.grubhub.com/restaurant/ayame-hibachi--sushi-526-washington-st-hoboken/296370?affiliate=1131&utm_source=foursquare-affiliate-network&utm_medium=affiliate&utm_campaign=1131&utm_content=296370',
#         'provider': {'name': 'grubhub',
#          'icon': {'prefix': 'https://fastly.4sqi.net/img/general/cap/',
#           'sizes': [40, 50],
#           'name': '/delivery_provider_grubhub_20180129.png'}}},
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4dbc9859f7b1ab37dd636d12-12'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4d9368407b5ea1437d14c8b8',
#        'name': "Mamoun's Falafel",
#        'location': {'address': '502 Washington St',
#         'crossStreet': 'at 5th St',
#         'lat': 40.742302660378776,
#         'lng': -74.02946547322561,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 40.742302660378776,
#           'lng': -74.02946547322561}],
#         'distance': 269,
#         'postalCode': '07030',
#         'cc': 'US',
#         'city': 'Hoboken',
#         'state': 'NJ',
#         'country': 'United States',
#         'formattedAddress': ['502 Washington St (at 5th St)',
#          'Hoboken, NJ 07030',
#          'United States']},
#        'categories': [{'id': '4bf58dd8d48988d10b941735',
#          'name': 'Falafel Restaurant',
#          'pluralName': 'Falafel Restaurants',
#          'shortName': 'Falafel',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/falafel_',
#           'suffix': '.png'},
#          'primary': True}],
#        'delivery': {'id': '277402',
#         'url': 'https://www.grubhub.com/restaurant/mamouns-falafel-restaurant-502-washington-st-hoboken/277402?affiliate=1131&utm_source=foursquare-affiliate-network&utm_medium=affiliate&utm_campaign=1131&utm_content=277402',
#         'provider': {'name': 'grubhub',
#          'icon': {'prefix': 'https://fastly.4sqi.net/img/general/cap/',
#           'sizes': [40, 50],
#           'name': '/delivery_provider_grubhub_20180129.png'}}},
#        'photos': {'count': 0, 'groups': []},
#        'venuePage': {'id': '43307012'}},
#       'referralId': 'e-0-4d9368407b5ea1437d14c8b8-13'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4b784457f964a520cdc02ee3',
#        'name': 'Fleet Feet Sports',
#        'location': {'address': '604 Washington St',
#         'crossStreet': '6th St',
#         'lat': 40.74364646969993,
#         'lng': -74.02907764645921,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 40.74364646969993,
#           'lng': -74.02907764645921}],
#         'distance': 280,
#         'postalCode': '07030',
#         'cc': 'US',
#         'city': 'Hoboken',
#         'state': 'NJ',
#         'country': 'United States',
#         'formattedAddress': ['604 Washington St (6th St)',
#          'Hoboken, NJ 07030',
#          'United States']},
#        'categories': [{'id': '4bf58dd8d48988d1f2941735',
#          'name': 'Sporting Goods Shop',
#          'pluralName': 'Sporting Goods Shops',
#          'shortName': 'Sporting Goods',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/sports_outdoors_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4b784457f964a520cdc02ee3-14'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4a7eff1cf964a5206ff21fe3',
#        'name': 'Court Street Bar & Restaurant',
#        'location': {'address': '61 6th St',
#         'crossStreet': 'at Court St',
#         'lat': 40.74332213312085,
#         'lng': -74.02861473442614,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 40.74332213312085,
#           'lng': -74.02861473442614}],
#         'distance': 317,
#         'postalCode': '07030',
#         'cc': 'US',
#         'city': 'Hoboken',
#         'state': 'NJ',
#         'country': 'United States',
#         'formattedAddress': ['61 6th St (at Court St)',
#          'Hoboken, NJ 07030',
#          'United States']},
#        'categories': [{'id': '4bf58dd8d48988d14e941735',
#          'name': 'American Restaurant',
#          'pluralName': 'American Restaurants',
#          'shortName': 'American',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/default_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []},
#        'venuePage': {'id': '84003162'}},
#       'referralId': 'e-0-4a7eff1cf964a5206ff21fe3-15'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '49f26862f964a520296a1fe3',
#        'name': "Zack's Oak Bar & Restaurant",
#        'location': {'address': '232 Willow Ave',
#         'crossStreet': 'at 3rd St',
#         'lat': 40.74064008523523,
#         'lng': -74.03382573472544,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 40.74064008523523,
#           'lng': -74.03382573472544}],
#         'distance': 321,
#         'postalCode': '07030',
#         'cc': 'US',
#         'city': 'Hoboken',
#         'state': 'NJ',
#         'country': 'United States',
#         'formattedAddress': ['232 Willow Ave (at 3rd St)',
#          'Hoboken, NJ 07030',
#          'United States']},
#        'categories': [{'id': '4bf58dd8d48988d14e941735',
#          'name': 'American Restaurant',
#          'pluralName': 'American Restaurants',
#          'shortName': 'American',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/default_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []},
#        'venuePage': {'id': '60041199'}},
#       'referralId': 'e-0-49f26862f964a520296a1fe3-16'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '49f37b88f964a520a26a1fe3',
#        'name': 'Empire Coffee & Tea',
#        'location': {'address': '338 Bloomfield St',
#         'crossStreet': 'at 4th St',
#         'lat': 40.74137492076492,
#         'lng': -74.0305153338276,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 40.74137492076492,
#           'lng': -74.0305153338276}],
#         'distance': 266,
#         'postalCode': '07030',
#         'cc': 'US',
#         'city': 'Hoboken',
#         'state': 'NJ',
#         'country': 'United States',
#         'formattedAddress': ['338 Bloomfield St (at 4th St)',
#          'Hoboken, NJ 07030',
#          'United States']},
#        'categories': [{'id': '4bf58dd8d48988d1e0931735',
#          'name': 'Coffee Shop',
#          'pluralName': 'Coffee Shops',
#          'shortName': 'Coffee Shop',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/coffeeshop_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []},
#        'venuePage': {'id': '119534416'}},
#       'referralId': 'e-0-49f37b88f964a520a26a1fe3-17'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4d3b7bdd687ca35d1e8a94c4',
#        'name': 'Old German Bakery',
#        'location': {'address': '332 Washington St',
#         'crossStreet': 'at 4th St',
#         'lat': 40.74114653903486,
#         'lng': -74.02980981300425,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 40.74114653903486,
#           'lng': -74.02980981300425}],
#         'distance': 323,
#         'postalCode': '07030',
#         'cc': 'US',
#         'city': 'Hoboken',
#         'state': 'NJ',
#         'country': 'United States',
#         'formattedAddress': ['332 Washington St (at 4th St)',
#          'Hoboken, NJ 07030',
#          'United States']},
#        'categories': [{'id': '4bf58dd8d48988d16a941735',
#          'name': 'Bakery',
#          'pluralName': 'Bakeries',
#          'shortName': 'Bakery',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/bakery_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4d3b7bdd687ca35d1e8a94c4-18'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '58e7ed715f67173549fe6246',
#        'name': 'Bluestone Lane',
#        'location': {'address': '409 Washington St',
#         'lat': 40.7416010355079,
#         'lng': -74.02940965731437,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 40.7416010355079,
#           'lng': -74.02940965731437}],
#         'distance': 314,
#         'postalCode': '07030',
#         'cc': 'US',
#         'city': 'Hoboken',
#         'state': 'NJ',
#         'country': 'United States',
#         'formattedAddress': ['409 Washington St',
#          'Hoboken, NJ 07030',
#          'United States']},
#        'categories': [{'id': '4bf58dd8d48988d1e0931735',
#          'name': 'Coffee Shop',
#          'pluralName': 'Coffee Shops',
#          'shortName': 'Coffee Shop',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/coffeeshop_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-58e7ed715f67173549fe6246-19'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '49dfb562f964a52001611fe3',
#        'name': "Ben & Jerry's",
#        'location': {'address': '405 Washington St',
#         'lat': 40.7414305,
#         'lng': -74.0294837,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 40.7414305,
#           'lng': -74.0294837}],
#         'distance': 321,
#         'postalCode': '07030',
#         'cc': 'US',
#         'city': 'Hoboken',
#         'state': 'NJ',
#         'country': 'United States',
#         'formattedAddress': ['405 Washington St',
#          'Hoboken, NJ 07030',
#          'United States']},
#        'categories': [{'id': '4bf58dd8d48988d1c9941735',
#          'name': 'Ice Cream Shop',
#          'pluralName': 'Ice Cream Shops',
#          'shortName': 'Ice Cream',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/icecream_',
#           'suffix': '.png'},
#          'primary': True}],
#        'delivery': {'id': '78617',
#         'url': 'https://www.grubhub.com/restaurant/ben--jerrys-405-washington-st-hoboken/78617?affiliate=1131&utm_source=foursquare-affiliate-network&utm_medium=affiliate&utm_campaign=1131&utm_content=78617',
#         'provider': {'name': 'grubhub',
#          'icon': {'prefix': 'https://fastly.4sqi.net/img/general/cap/',
#           'sizes': [40, 50],
#           'name': '/delivery_provider_grubhub_20180129.png'}}},
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-49dfb562f964a52001611fe3-20'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4ca50f407334236a60ef1258',
#        'name': "Grimaldi's",
#        'location': {'address': '411 Washington St',
#         'crossStreet': 'btwn 4th and 5th',
#         'lat': 40.74167406908621,
#         'lng': -74.02957750973907,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 40.74167406908621,
#           'lng': -74.02957750973907}],
#         'distance': 297,
#         'postalCode': '07030',
#         'cc': 'US',
#         'city': 'Hoboken',
#         'state': 'NJ',
#         'country': 'United States',
#         'formattedAddress': ['411 Washington St (btwn 4th and 5th)',
#          'Hoboken, NJ 07030',
#          'United States']},
#        'categories': [{'id': '4bf58dd8d48988d1ca941735',
#          'name': 'Pizza Place',
#          'pluralName': 'Pizza Places',
#          'shortName': 'Pizza',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/pizza_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []},
#        'venuePage': {'id': '57687383'}},
#       'referralId': 'e-0-4ca50f407334236a60ef1258-21'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '53ed3b37498e4151087521a9',
#        'name': 'Bareburger',
#        'location': {'address': '515 Washington St',
#         'lat': 40.742693954701245,
#         'lng': -74.02907006819072,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 40.742693954701245,
#           'lng': -74.02907006819072}],
#         'distance': 286,
#         'postalCode': '07030',
#         'cc': 'US',
#         'city': 'Hoboken',
#         'state': 'NJ',
#         'country': 'United States',
#         'formattedAddress': ['515 Washington St',
#          'Hoboken, NJ 07030',
#          'United States']},
#        'categories': [{'id': '4bf58dd8d48988d16c941735',
#          'name': 'Burger Joint',
#          'pluralName': 'Burger Joints',
#          'shortName': 'Burgers',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/burger_',
#           'suffix': '.png'},
#          'primary': True}],
#        'delivery': {'id': '297961',
#         'url': 'https://www.grubhub.com/restaurant/bareburger-515-washington-st-hoboken/297961?affiliate=1131&utm_source=foursquare-affiliate-network&utm_medium=affiliate&utm_campaign=1131&utm_content=297961',
#         'provider': {'name': 'grubhub',
#          'icon': {'prefix': 'https://fastly.4sqi.net/img/general/cap/',
#           'sizes': [40, 50],
#           'name': '/delivery_provider_grubhub_20180129.png'}}},
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-53ed3b37498e4151087521a9-22'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '5bede1881953f3002c8bd30e',
#        'name': 'Warby Parker',
#        'location': {'address': '538 Washington Street',
#         'lat': 40.743458,
#         'lng': -74.029408,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 40.743458,
#           'lng': -74.029408}],
#         'distance': 250,
#         'postalCode': '07030',
#         'cc': 'US',
#         'city': 'Hoboken',
#         'state': 'NJ',
#         'country': 'United States',
#         'formattedAddress': ['538 Washington Street',
#          'Hoboken, NJ 07030',
#          'United States']},
#        'categories': [{'id': '4d954afda243a5684865b473',
#          'name': 'Optical Shop',
#          'pluralName': 'Optical Shops',
#          'shortName': 'Optical',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/medical_opticalshop_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-5bede1881953f3002c8bd30e-23'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4d4218cd607b6dcb31df08c6',
#        'name': 'Cork City Pub',
#        'location': {'address': '239 Bloomfield St',
#         'crossStreet': 'at 3rd St',
#         'lat': 40.74010486484954,
#         'lng': -74.03086819003738,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 40.74010486484954,
#           'lng': -74.03086819003738}],
#         'distance': 378,
#         'postalCode': '07030',
#         'cc': 'US',
#         'city': 'Hoboken',
#         'state': 'NJ',
#         'country': 'United States',
#         'formattedAddress': ['239 Bloomfield St (at 3rd St)',
#          'Hoboken, NJ 07030',
#          'United States']},
#        'categories': [{'id': '4bf58dd8d48988d11b941735',
#          'name': 'Pub',
#          'pluralName': 'Pubs',
#          'shortName': 'Pub',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/nightlife/pub_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []},
#        'venuePage': {'id': '50649981'}},
#       'referralId': 'e-0-4d4218cd607b6dcb31df08c6-24'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '51c892e02fc6ae7a5278a97e',
#        'name': 'Hudson River Athletics',
#        'location': {'address': '333 Newark street',
#         'lat': 40.745562683353086,
#         'lng': -74.0328410494832,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 40.745562683353086,
#           'lng': -74.0328410494832}],
#         'distance': 254,
#         'postalCode': '07030',
#         'cc': 'US',
#         'city': 'Hoboken',
#         'state': 'NJ',
#         'country': 'United States',
#         'formattedAddress': ['333 Newark street',
#          'Hoboken, NJ 07030',
#          'United States']},
#        'categories': [{'id': '4bf58dd8d48988d175941735',
#          'name': 'Gym / Fitness Center',
#          'pluralName': 'Gyms or Fitness Centers',
#          'shortName': 'Gym / Fitness',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/gym_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []},
#        'venuePage': {'id': '68113182'}},
#       'referralId': 'e-0-51c892e02fc6ae7a5278a97e-25'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '49e2a407f964a52045621fe3',
#        'name': 'Cucharamama',
#        'location': {'address': '233 Clinton St',
#         'crossStreet': 'btwn 2nd & 3rd St.',
#         'lat': 40.7408073760094,
#         'lng': -74.03458175351923,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 40.7408073760094,
#           'lng': -74.03458175351923}],
#         'distance': 334,
#         'postalCode': '07030',
#         'cc': 'US',
#         'city': 'Hoboken',
#         'state': 'NJ',
#         'country': 'United States',
#         'formattedAddress': ['233 Clinton St (btwn 2nd & 3rd St.)',
#          'Hoboken, NJ 07030',
#          'United States']},
#        'categories': [{'id': '4bf58dd8d48988d1cd941735',
#          'name': 'South American Restaurant',
#          'pluralName': 'South American Restaurants',
#          'shortName': 'South American',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/argentinian_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-49e2a407f964a52045621fe3-26'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4a453f9cf964a520f4a71fe3',
#        'name': 'Zafra',
#        'location': {'address': '301 Willow Ave',
#         'crossStreet': 'at 3rd St',
#         'lat': 40.740659471339825,
#         'lng': -74.03380200797542,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 40.740659471339825,
#           'lng': -74.03380200797542}],
#         'distance': 318,
#         'postalCode': '07030',
#         'cc': 'US',
#         'city': 'Hoboken',
#         'state': 'NJ',
#         'country': 'United States',
#         'formattedAddress': ['301 Willow Ave (at 3rd St)',
#          'Hoboken, NJ 07030',
#          'United States']},
#        'categories': [{'id': '4bf58dd8d48988d154941735',
#          'name': 'Cuban Restaurant',
#          'pluralName': 'Cuban Restaurants',
#          'shortName': 'Cuban',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/cuban_',
#           'suffix': '.png'},
#          'primary': True}],
#        'delivery': {'id': '622030',
#         'url': 'https://www.grubhub.com/restaurant/zafra-301-willow-ave-hoboken/622030?affiliate=1131&utm_source=foursquare-affiliate-network&utm_medium=affiliate&utm_campaign=1131&utm_content=622030',
#         'provider': {'name': 'grubhub',
#          'icon': {'prefix': 'https://fastly.4sqi.net/img/general/cap/',
#           'sizes': [40, 50],
#           'name': '/delivery_provider_grubhub_20180129.png'}}},
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4a453f9cf964a520f4a71fe3-27'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4eb1b6859adfb95b77765bf9',
#        'name': 'The Cuban',
#        'location': {'address': '333 Washington St',
#         'crossStreet': '4th street',
#         'lat': 40.74101245470124,
#         'lng': -74.02973234956126,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 40.74101245470124,
#           'lng': -74.02973234956126}],
#         'distance': 338,
#         'postalCode': '07030',
#         'cc': 'US',
#         'city': 'Hoboken',
#         'state': 'NJ',
#         'country': 'United States',
#         'formattedAddress': ['333 Washington St (4th street)',
#          'Hoboken, NJ 07030',
#          'United States']},
#        'categories': [{'id': '4bf58dd8d48988d154941735',
#          'name': 'Cuban Restaurant',
#          'pluralName': 'Cuban Restaurants',
#          'shortName': 'Cuban',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/cuban_',
#           'suffix': '.png'},
#          'primary': True}],
#        'delivery': {'id': '1171664',
#         'url': 'https://www.grubhub.com/restaurant/the-cuban-333-washington-st-hoboken/1171664?affiliate=1131&utm_source=foursquare-affiliate-network&utm_medium=affiliate&utm_campaign=1131&utm_content=1171664',
#         'provider': {'name': 'grubhub',
#          'icon': {'prefix': 'https://fastly.4sqi.net/img/general/cap/',
#           'sizes': [40, 50],
#           'name': '/delivery_provider_grubhub_20180129.png'}}},
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4eb1b6859adfb95b77765bf9-28'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '57f83f7acd10164c2ec1956f',
#        'name': 'Tutta Pesca',
#        'location': {'address': '155 3rd St',
#         'crossStreet': 'Bloomfield',
#         'lat': 40.7401625051114,
#         'lng': -74.03128399753021,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 40.7401625051114,
#           'lng': -74.03128399753021}],
#         'distance': 361,
#         'postalCode': '07030',
#         'cc': 'US',
#         'city': 'Hoboken',
#         'state': 'NJ',
#         'country': 'United States',
#         'formattedAddress': ['155 3rd St (Bloomfield)',
#          'Hoboken, NJ 07030',
#          'United States']},
#        'categories': [{'id': '4bf58dd8d48988d1ce941735',
#          'name': 'Seafood Restaurant',
#          'pluralName': 'Seafood Restaurants',
#          'shortName': 'Seafood',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/seafood_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-57f83f7acd10164c2ec1956f-29'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4cdb36c1958f236a15a7ab03',
#        'name': 'Robongi',
#        'location': {'address': '520 Washington St',
#         'crossStreet': '5th St.',
#         'lat': 40.74287866510769,
#         'lng': -74.0292797646991,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 40.74287866510769,
#           'lng': -74.0292797646991}],
#         'distance': 265,
#         'postalCode': '07030',
#         'cc': 'US',
#         'city': 'Hoboken',
#         'state': 'NJ',
#         'country': 'United States',
#         'formattedAddress': ['520 Washington St (5th St.)',
#          'Hoboken, NJ 07030',
#          'United States']},
#        'categories': [{'id': '4bf58dd8d48988d1d2941735',
#          'name': 'Sushi Restaurant',
#          'pluralName': 'Sushi Restaurants',
#          'shortName': 'Sushi',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/sushi_',
#           'suffix': '.png'},
#          'primary': True}],
#        'delivery': {'id': '70931',
#         'url': 'https://www.grubhub.com/restaurant/robongi-restaurant-hoboken-520-washington-st-hoboken/70931?affiliate=1131&utm_source=foursquare-affiliate-network&utm_medium=affiliate&utm_campaign=1131&utm_content=70931',
#         'provider': {'name': 'grubhub',
#          'icon': {'prefix': 'https://fastly.4sqi.net/img/general/cap/',
#           'sizes': [40, 50],
#           'name': '/delivery_provider_grubhub_20180129.png'}}},
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4cdb36c1958f236a15a7ab03-30'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '57127a9d498e648da026a585',
#        'name': 'Aether Game Cafe',
#        'location': {'address': '519 Washington St',
#         'crossStreet': 'btwn 5th & 6th',
#         'lat': 40.742812745885644,
#         'lng': -74.02918367562344,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 40.742812745885644,
#           'lng': -74.02918367562344}],
#         'distance': 274,
#         'postalCode': '07030',
#         'cc': 'US',
#         'city': 'Hoboken',
#         'state': 'NJ',
#         'country': 'United States',
#         'formattedAddress': ['519 Washington St (btwn 5th & 6th)',
#          'Hoboken, NJ 07030',
#          'United States']},
#        'categories': [{'id': '4bf58dd8d48988d18d941735',
#          'name': 'Gaming Cafe',
#          'pluralName': 'Gaming Cafes',
#          'shortName': 'Gaming Cafe',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/gamingcafe_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-57127a9d498e648da026a585-31'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4b93cf35f964a520c65234e3',
#        'name': 'Church Square Dog Park',
#        'location': {'address': '401 Willow Ave.',
#         'crossStreet': '4th & Willow',
#         'lat': 40.742203138352124,
#         'lng': -74.03303786884511,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 40.742203138352124,
#           'lng': -74.03303786884511}],
#         'distance': 134,
#         'postalCode': '07030',
#         'cc': 'US',
#         'city': 'Hoboken',
#         'state': 'NJ',
#         'country': 'United States',
#         'formattedAddress': ['401 Willow Ave. (4th & Willow)',
#          'Hoboken, NJ 07030',
#          'United States']},
#        'categories': [{'id': '4bf58dd8d48988d1e5941735',
#          'name': 'Dog Run',
#          'pluralName': 'Dog Runs',
#          'shortName': 'Dog Run',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/parks_outdoors/dogrun_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4b93cf35f964a520c65234e3-32'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4eb039c4e5fa708105c903ac',
#        'name': 'Hoboken Pet',
#        'location': {'address': '524 Washington St',
#         'lat': 40.74303498433573,
#         'lng': -74.02924404967993,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 40.74303498433573,
#           'lng': -74.02924404967993}],
#         'distance': 265,
#         'postalCode': '07030',
#         'cc': 'US',
#         'city': 'Hoboken',
#         'state': 'NJ',
#         'country': 'United States',
#         'formattedAddress': ['524 Washington St',
#          'Hoboken, NJ 07030',
#          'United States']},
#        'categories': [{'id': '4bf58dd8d48988d100951735',
#          'name': 'Pet Store',
#          'pluralName': 'Pet Stores',
#          'shortName': 'Pet Store',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/pet_store_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []},
#        'venuePage': {'id': '37704701'}},
#       'referralId': 'e-0-4eb039c4e5fa708105c903ac-33'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4ad12c5ef964a5203ddd20e3',
#        'name': "Moran's Pub",
#        'location': {'address': '501 Garden St',
#         'crossStreet': '5th Street',
#         'lat': 40.742552761953135,
#         'lng': -74.03119210059499,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 40.742552761953135,
#           'lng': -74.03119210059499}],
#         'distance': 130,
#         'postalCode': '07030',
#         'cc': 'US',
#         'city': 'Hoboken',
#         'state': 'NJ',
#         'country': 'United States',
#         'formattedAddress': ['501 Garden St (5th Street)',
#          'Hoboken, NJ 07030',
#          'United States']},
#        'categories': [{'id': '4bf58dd8d48988d116941735',
#          'name': 'Bar',
#          'pluralName': 'Bars',
#          'shortName': 'Bar',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/nightlife/pub_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []},
#        'venuePage': {'id': '81088402'}},
#       'referralId': 'e-0-4ad12c5ef964a5203ddd20e3-34'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4a9ac1b1f964a520813220e3',
#        'name': "Benny Tudino's",
#        'location': {'address': '622 Washington St',
#         'crossStreet': 'btwn 6th & 7th',
# ...
#           'sizes': [40, 50],
#           'name': '/delivery_provider_grubhub_20180129.png'}}},
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4af5d847f964a520aefd21e3-87'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4c13f99d7f7f2d7fda1ae068',
#        'name': 'DeBaun Center For Performing Arts',
#        'location': {'address': '500 Hudson St',
#         'lat': 40.742485181523456,
#         'lng': -74.02769242999422,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 40.742485181523456,
#           'lng': -74.02769242999422}],
#         'distance': 405,
#         'postalCode': '07030',
#         'cc': 'US',
#         'city': 'Hoboken',
#         'state': 'NJ',
#         'country': 'United States',
#         'formattedAddress': ['500 Hudson St',
#          'Hoboken, NJ 07030',
#          'United States']},
#        'categories': [{'id': '5032792091d4c4b30a586d5c',
#          'name': 'Concert Hall',
#          'pluralName': 'Concert Halls',
#          'shortName': 'Concert Hall',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/arts_entertainment/musicvenue_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4c13f99d7f7f2d7fda1ae068-88'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4baa30e4f964a520e1513ae3',
#        'name': 'Stevens Park Dog Run',
#        'location': {'address': 'Hudson St',
#         'crossStreet': 'btwn 4th & 5th St',
#         'lat': 40.7415352934731,
#         'lng': -74.02821400762662,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 40.7415352934731,
#           'lng': -74.02821400762662}],
#         'distance': 402,
#         'postalCode': '07030',
#         'cc': 'US',
#         'city': 'Hoboken',
#         'state': 'NJ',
#         'country': 'United States',
#         'formattedAddress': ['Hudson St (btwn 4th & 5th St)',
#          'Hoboken, NJ 07030',
#          'United States']},
#        'categories': [{'id': '4bf58dd8d48988d1e5941735',
#          'name': 'Dog Run',
#          'pluralName': 'Dog Runs',
#          'shortName': 'Dog Run',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/parks_outdoors/dogrun_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4baa30e4f964a520e1513ae3-89'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '578d640f498e64162d22e6e9',
#        'name': "Jun's Macaron Gelato",
#        'location': {'address': '410 Washington St',
#         'lat': 40.741696780507226,
#         'lng': -74.02965104741823,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 40.741696780507226,
#           'lng': -74.02965104741823}],
#         'distance': 291,
#         'postalCode': '07030',
#         'cc': 'US',
#         'city': 'Hoboken',
#         'state': 'NJ',
#         'country': 'United States',
#         'formattedAddress': ['410 Washington St',
#          'Hoboken, NJ 07030',
#          'United States']},
#        'categories': [{'id': '4bf58dd8d48988d1d0941735',
#          'name': 'Dessert Shop',
#          'pluralName': 'Dessert Shops',
#          'shortName': 'Desserts',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/dessert_',
#           'suffix': '.png'},
#          'primary': True}],
#        'delivery': {'id': '531293',
#         'url': 'https://www.grubhub.com/restaurant/juns-macaron-gelato-410-washington-st-hoboken/531293?affiliate=1131&utm_source=foursquare-affiliate-network&utm_medium=affiliate&utm_campaign=1131&utm_content=531293',
#         'provider': {'name': 'grubhub',
#          'icon': {'prefix': 'https://fastly.4sqi.net/img/general/cap/',
#           'sizes': [40, 50],
#           'name': '/delivery_provider_grubhub_20180129.png'}}},
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-578d640f498e64162d22e6e9-90'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4b7f4011f964a5205f2230e3',
#        'name': 'Symposia Community Book Store',
#        'location': {'address': '510 Washington St',
#         'crossStreet': '5th and Washington',
#         'lat': 40.742582692129005,
#         'lng': -74.02939078496166,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 40.742582692129005,
#           'lng': -74.02939078496166}],
#         'distance': 264,
#         'postalCode': '07030',
#         'cc': 'US',
#         'city': 'Hoboken',
#         'state': 'NJ',
#         'country': 'United States',
#         'formattedAddress': ['510 Washington St (5th and Washington)',
#          'Hoboken, NJ 07030',
#          'United States']},
#        'categories': [{'id': '4bf58dd8d48988d114951735',
#          'name': 'Bookstore',
#          'pluralName': 'Bookstores',
#          'shortName': 'Bookstore',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/bookstore_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4b7f4011f964a5205f2230e3-91'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '49eabe84f964a52090661fe3',
#        'name': 'QDOBA Mexican Eats',
#        'location': {'address': '400 Washington St',
#         'lat': 40.7414127,
#         'lng': -74.0299258,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 40.7414127,
#           'lng': -74.0299258}],
#         'distance': 295,
#         'postalCode': '07030',
#         'cc': 'US',
#         'city': 'Hoboken',
#         'state': 'NJ',
#         'country': 'United States',
#         'formattedAddress': ['400 Washington St',
#          'Hoboken, NJ 07030',
#          'United States']},
#        'categories': [{'id': '4bf58dd8d48988d1c1941735',
#          'name': 'Mexican Restaurant',
#          'pluralName': 'Mexican Restaurants',
#          'shortName': 'Mexican',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/mexican_',
#           'suffix': '.png'},
#          'primary': True}],
#        'delivery': {'id': '70927',
#         'url': 'https://www.grubhub.com/restaurant/qdoba-mexican-grill-hoboken-400-washington-st-hoboken/70927?affiliate=1131&utm_source=foursquare-affiliate-network&utm_medium=affiliate&utm_campaign=1131&utm_content=70927',
#         'provider': {'name': 'grubhub',
#          'icon': {'prefix': 'https://fastly.4sqi.net/img/general/cap/',
#           'sizes': [40, 50],
#           'name': '/delivery_provider_grubhub_20180129.png'}}},
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-49eabe84f964a52090661fe3-92'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4b44d83ef964a520f4fd25e3',
#        'name': "Mario's Classic Pizza Café",
#        'location': {'address': '742 Garden St',
#         'crossStreet': '8th',
#         'lat': 40.74636362311963,
#         'lng': -74.03015162892913,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 40.74636362311963,
#           'lng': -74.03015162892913}],
#         'distance': 388,
#         'postalCode': '07030',
#         'cc': 'US',
#         'city': 'Hoboken',
#         'state': 'NJ',
#         'country': 'United States',
#         'formattedAddress': ['742 Garden St (8th)',
#          'Hoboken, NJ 07030',
#          'United States']},
#        'categories': [{'id': '4bf58dd8d48988d1ca941735',
#          'name': 'Pizza Place',
#          'pluralName': 'Pizza Places',
#          'shortName': 'Pizza',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/pizza_',
#           'suffix': '.png'},
#          'primary': True}],
#        'delivery': {'id': '70913',
#         'url': 'https://www.grubhub.com/restaurant/marios-classic-pizza-742-garden-st-hoboken/70913?affiliate=1131&utm_source=foursquare-affiliate-network&utm_medium=affiliate&utm_campaign=1131&utm_content=70913',
#         'provider': {'name': 'grubhub',
#          'icon': {'prefix': 'https://fastly.4sqi.net/img/general/cap/',
#           'sizes': [40, 50],
#           'name': '/delivery_provider_grubhub_20180129.png'}}},
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4b44d83ef964a520f4fd25e3-93'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4b804bcaf964a5204d6530e3',
#        'name': 'GameStop',
#        'location': {'address': '408 Washington St',
#         'lat': 40.741620549066845,
#         'lng': -74.02966563417021,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 40.741620549066845,
#           'lng': -74.02966563417021}],
#         'distance': 295,
#         'postalCode': '07030',
#         'cc': 'US',
#         'city': 'Hoboken',
#         'state': 'NJ',
#         'country': 'United States',
#         'formattedAddress': ['408 Washington St',
#          'Hoboken, NJ 07030',
#          'United States']},
#        'categories': [{'id': '4bf58dd8d48988d10b951735',
#          'name': 'Video Game Store',
#          'pluralName': 'Video Game Stores',
#          'shortName': 'Video Games',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/videogames_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4b804bcaf964a5204d6530e3-94'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '5b5b1e0bd4cc9800394e3256',
#        'name': 'Hidden Grounds Coffee',
#        'location': {'address': '700 Garden St',
#         'crossStreet': '8th Street',
#         'lat': 40.745082,
#         'lng': -74.030464,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 40.745082,
#           'lng': -74.030464}],
#         'distance': 255,
#         'postalCode': '07030',
#         'cc': 'US',
#         'city': 'Hoboken',
#         'state': 'NJ',
#         'country': 'United States',
#         'formattedAddress': ['700 Garden St (8th Street)',
#          'Hoboken, NJ 07030',
#          'United States']},
#        'categories': [{'id': '4bf58dd8d48988d1e0931735',
#          'name': 'Coffee Shop',
#          'pluralName': 'Coffee Shops',
#          'shortName': 'Coffee Shop',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/coffeeshop_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-5b5b1e0bd4cc9800394e3256-95'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '5b857f112f97ec002c294c98',
#        'name': 'Soul Curry',
#        'location': {'address': '618 Washington St',
#         'lat': 40.744077,
#         'lng': -74.028975,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 40.744077,
#           'lng': -74.028975}],
#         'distance': 299,
#         'postalCode': '07030',
#         'cc': 'US',
#         'city': 'Hoboken',
#         'state': 'NJ',
#         'country': 'United States',
#         'formattedAddress': ['618 Washington St',
#          'Hoboken, NJ 07030',
#          'United States']},
#        'categories': [{'id': '4bf58dd8d48988d10f941735',
#          'name': 'Indian Restaurant',
#          'pluralName': 'Indian Restaurants',
#          'shortName': 'Indian',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/indian_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-5b857f112f97ec002c294c98-96'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '49cf90f2f964a520ae5a1fe3',
#        'name': "Willie McBride's",
#        'location': {'address': '616 Grand St',
#         'crossStreet': 'btwn 6th & 7th Ave.',
#         'lat': 40.745132558114484,
#         'lng': -74.03449741670644,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 40.745132558114484,
#           'lng': -74.03449741670644}],
#         'distance': 270,
#         'postalCode': '07030',
#         'cc': 'US',
#         'city': 'Hoboken',
#         'state': 'NJ',
#         'country': 'United States',
#         'formattedAddress': ['616 Grand St (btwn 6th & 7th Ave.)',
#          'Hoboken, NJ 07030',
#          'United States']},
#        'categories': [{'id': '4bf58dd8d48988d116941735',
#          'name': 'Bar',
#          'pluralName': 'Bars',
#          'shortName': 'Bar',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/nightlife/pub_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-49cf90f2f964a520ae5a1fe3-97'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4b5b4e5cf964a52043f328e3',
#        'name': 'Viva La Nails',
#        'location': {'address': '530 Washington St',
#         'lat': 40.74323200350975,
#         'lng': -74.02917528110068,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 40.74323200350975,
#           'lng': -74.02917528110068}],
#         'distance': 270,
#         'postalCode': '07030',
#         'cc': 'US',
#         'city': 'Hoboken',
#         'state': 'NJ',
#         'country': 'United States',
#         'formattedAddress': ['530 Washington St',
#          'Hoboken, NJ 07030',
#          'United States']},
#        'categories': [{'id': '4bf58dd8d48988d10c951735',
#          'name': 'Cosmetics Shop',
#          'pluralName': 'Cosmetics Shops',
#          'shortName': 'Cosmetics',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/beauty_cosmetic_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4b5b4e5cf964a52043f328e3-98'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '5106f9db830220a8f4821b31',
#        'name': 'Medicine Man Pharmacy',
#        'location': {'address': '511 Washington St',
#         'crossStreet': '5th Street',
#         'lat': 40.74285137270151,
#         'lng': -74.02933359146117,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 40.74285137270151,
#           'lng': -74.02933359146117}],
#         'distance': 261,
#         'postalCode': '07030',
#         'cc': 'US',
#         'city': 'Hoboken',
#         'state': 'NJ',
#         'country': 'United States',
#         'formattedAddress': ['511 Washington St (5th Street)',
#          'Hoboken, NJ 07030',
#          'United States']},
#        'categories': [{'id': '4bf58dd8d48988d10f951735',
#          'name': 'Pharmacy',
#          'pluralName': 'Pharmacies',
#          'shortName': 'Pharmacy',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/pharmacy_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []},
#        'venuePage': {'id': '46953460'}},
#       'referralId': 'e-0-5106f9db830220a8f4821b31-99'}]}]}}

# %%
def get_category_type(row):
    try:
        categories_list = row['categories']
    except:
        categories_list = row['venue.categories']
        
    if len(categories_list) == 0:
        return None
    else:
        return categories_list[0]['name']

# %%
#pull the actual data from the Foursquare API

venues = results['response']['groups'][0]['items']
nearby_venues = json_normalize(venues)
filtered_columns = ['venue.name', 'venue.id', 'venue.categories', 'venue.location.lat', 'venue.location.lng']
nearby_venues
nearby_venues =nearby_venues.loc[:, filtered_columns]

# filter the category for each row
nearby_venues['venue.categories'] = nearby_venues.apply(get_category_type, axis=1)

nearby_venues
# Out:
#                            venue.name                  venue.id  \
# 0      Work It Out-A Fitness Boutique  4cdf46dadb125481eb4236ce
# 1                  Church Square Park  49e9e49df964a5200a661fe3
# 2           Onieal's Restaurant & Bar  45e9482df964a52075431fe3
# 3                               Sweet  4a4e740ff964a5207bae1fe3
# 4                           Grand Vin  56d3b920498ec4e1c67c0907
# 5               Hoboken General Store  4b6b0a45f964a520a5ee2be3
# 6                          Karma Kafe  582dfc9565be5809f6a964ed
# 7                             O'Bagel  56daf06fcd107605ef3d86ea
# 8                         Kung Fu Tea  57168865498e9517f09fa03d
# 9                       Anthropologie  51f1c7e1498e7425c21efab6
# 10                       Dom's Bakery  4b660130f964a520ce0d2be3
# 11                       Fiore's Deli  4a1098a2f964a520e3761fe3
# 12              Ayame Hibachi & Sushi  4dbc9859f7b1ab37dd636d12
# 13                   Mamoun's Falafel  4d9368407b5ea1437d14c8b8
# 14                  Fleet Feet Sports  4b784457f964a520cdc02ee3
# 15      Court Street Bar & Restaurant  4a7eff1cf964a5206ff21fe3
# 16        Zack's Oak Bar & Restaurant  49f26862f964a520296a1fe3
# 17                Empire Coffee & Tea  49f37b88f964a520a26a1fe3
# 18                  Old German Bakery  4d3b7bdd687ca35d1e8a94c4
# 19                     Bluestone Lane  58e7ed715f67173549fe6246
# 20                      Ben & Jerry's  49dfb562f964a52001611fe3
# 21                         Grimaldi's  4ca50f407334236a60ef1258
# 22                         Bareburger  53ed3b37498e4151087521a9
# 23                       Warby Parker  5bede1881953f3002c8bd30e
# 24                      Cork City Pub  4d4218cd607b6dcb31df08c6
# 25             Hudson River Athletics  51c892e02fc6ae7a5278a97e
# 26                        Cucharamama  49e2a407f964a52045621fe3
# 27                              Zafra  4a453f9cf964a520f4a71fe3
# 28                          The Cuban  4eb1b6859adfb95b77765bf9
# 29                        Tutta Pesca  57f83f7acd10164c2ec1956f
# 30                            Robongi  4cdb36c1958f236a15a7ab03
# 31                   Aether Game Cafe  57127a9d498e648da026a585
# 32             Church Square Dog Park  4b93cf35f964a520c65234e3
# 33                        Hoboken Pet  4eb039c4e5fa708105c903ac
# 34                        Moran's Pub  4ad12c5ef964a5203ddd20e3
# 35                     Benny Tudino's  4a9ac1b1f964a520813220e3
# 86                     Finnegan's Pub  522cb84211d20c34ef82194f
# 87                     H&S Giovanni's  4af5d847f964a520aefd21e3
# 88  DeBaun Center For Performing Arts  4c13f99d7f7f2d7fda1ae068
# 89               Stevens Park Dog Run  4baa30e4f964a520e1513ae3
# 90               Jun's Macaron Gelato  578d640f498e64162d22e6e9
# 91      Symposia Community Book Store  4b7f4011f964a5205f2230e3
# 92                 QDOBA Mexican Eats  49eabe84f964a52090661fe3
# 93         Mario's Classic Pizza Café  4b44d83ef964a520f4fd25e3
# 94                           GameStop  4b804bcaf964a5204d6530e3
# 95              Hidden Grounds Coffee  5b5b1e0bd4cc9800394e3256
# 96                         Soul Curry  5b857f112f97ec002c294c98
# 97                   Willie McBride's  49cf90f2f964a520ae5a1fe3
# 98                      Viva La Nails  4b5b4e5cf964a52043f328e3
# 99              Medicine Man Pharmacy  5106f9db830220a8f4821b31
#
#              venue.categories  venue.location.lat  venue.location.lng
# 0        Gym / Fitness Center           40.744356          -74.032567
# 1                        Park           40.742152          -74.032230
# 2                         Pub           40.741608          -74.032304
# 3                      Bakery           40.741623          -74.031523
# 4                Cocktail Bar           40.743209          -74.035099
# 5               Deli / Bodega           40.743148          -74.033030
# 6           Indian Restaurant           40.742373          -74.029376
# 7                  Bagel Shop           40.743603          -74.029173
# 8             Bubble Tea Shop           40.743347          -74.029379
# 9               Women's Store           40.741838          -74.029662
# 10                     Bakery           40.743387          -74.034836
# 11              Deli / Bodega           40.743019          -74.036183
# 12           Sushi Restaurant           40.743105          -74.029213
# 13         Falafel Restaurant           40.742303          -74.029465
# 14        Sporting Goods Shop           40.743646          -74.029078
# 15        American Restaurant           40.743322          -74.028615
# 16        American Restaurant           40.740640          -74.033826
# 17                Coffee Shop           40.741375          -74.030515
# 18                     Bakery           40.741147          -74.029810
# 19                Coffee Shop           40.741601          -74.029410
# 20             Ice Cream Shop           40.741430          -74.029484
# 21                Pizza Place           40.741674          -74.029578
# 22               Burger Joint           40.742694          -74.029070
# 23               Optical Shop           40.743458          -74.029408
# 24                        Pub           40.740105          -74.030868
# 25       Gym / Fitness Center           40.745563          -74.032841
# 26  South American Restaurant           40.740807          -74.034582
# 27           Cuban Restaurant           40.740659          -74.033802
# 28           Cuban Restaurant           40.741012          -74.029732
# 29         Seafood Restaurant           40.740163          -74.031284
# 30           Sushi Restaurant           40.742879          -74.029280
# 31                Gaming Cafe           40.742813          -74.029184
# 32                    Dog Run           40.742203          -74.033038
# 33                  Pet Store           40.743035          -74.029244
# 34                        Bar           40.742553          -74.031192
# 35                Pizza Place           40.744198          -74.028896
# 36                Yoga Studio           40.744102          -74.029007
# 37                Shoe Repair           40.745382          -74.032227
# 38                Pizza Place           40.744612          -74.035632
# 39         Italian Restaurant           40.746604          -74.031161
# 40  Latin American Restaurant           40.740620          -74.033490
# 41        Japanese Restaurant           40.741229          -74.029582
# 42         Italian Restaurant           40.742278          -74.030218
# 43              Jewelry Store           40.744487          -74.035039
# 44         Mexican Restaurant           40.741822          -74.031881
# 45        American Restaurant           40.746308          -74.030003
# 46                 Poke Place           40.742852          -74.029213
# 47             Sandwich Place           40.746401          -74.028310
# 48                   Boutique           40.744128          -74.029070
# 49                 Restaurant           40.742767          -74.029281
# 50         Falafel Restaurant           40.740090          -74.030374
# 51                  Juice Bar           40.740892          -74.029896
# 52             Cosmetics Shop           40.745624          -74.028501
# 53             Sandwich Place           40.745729          -74.028582
# 54             Cosmetics Shop           40.740587          -74.029787
# 55                Coffee Shop           40.743368          -74.029135
# 56                        Bar           40.742531          -74.036326
# 57         Mexican Restaurant           40.739599          -74.029981
# 58                Record Shop           40.739426          -74.030096
# 59            Bubble Tea Shop           40.743034          -74.029034
# 60                  Pet Store           40.743622          -74.037186
# 61          Korean Restaurant           40.742975          -74.029083
# 62           Business Service           40.745843          -74.033968
# 63                 Bagel Shop           40.744448          -74.028822
# 64                        Gym           40.743673          -74.028801
# 65                 Donut Shop           40.744912          -74.028920
# 66              Grocery Store           40.739068          -74.030388
# 67                 Sports Bar           40.744032          -74.028956
# 68                   Boutique           40.740742          -74.030123
# 69           Stationery Store           40.740540          -74.030045
# 70                   Dive Bar           40.740880          -74.029480
# 71                Pizza Place           40.739404          -74.034909
# 72                Coffee Shop           40.740723          -74.030130
# 73            Thai Restaurant           40.740103          -74.030955
# 74                  Pet Store           40.742272          -74.029896
# 75             Cosmetics Shop           40.740078          -74.030161
# 76         Salon / Barbershop           40.741393          -74.029723
# 77             Pilates Studio           40.740460          -74.027858
# 78         Mexican Restaurant           40.742509          -74.029496
# 79         Italian Restaurant           40.740996          -74.029827
# 80         Italian Restaurant           40.739127          -74.030450
# 81             Sandwich Place           40.742983          -74.029211
# 82               Liquor Store           40.743922          -74.036102
# 83            Thai Restaurant           40.741110          -74.029734
# 84                Yoga Studio           40.738853          -74.032275
# 85               Liquor Store           40.745235          -74.031448
# 86                        Pub           40.746477          -74.032032
# 87                Pizza Place           40.743508          -74.029017
# 88               Concert Hall           40.742485          -74.027692
# 89                    Dog Run           40.741535          -74.028214
# 90               Dessert Shop           40.741697          -74.029651
# 91                  Bookstore           40.742583          -74.029391
# 92         Mexican Restaurant           40.741413          -74.029926
# 93                Pizza Place           40.746364          -74.030152
# 94           Video Game Store           40.741621          -74.029666
# 95                Coffee Shop           40.745082          -74.030464
# 96          Indian Restaurant           40.744077          -74.028975
# 97                        Bar           40.745133          -74.034497
# 98             Cosmetics Shop           40.743232          -74.029175
# 99                   Pharmacy           40.742851          -74.029334

# %%
#fix the column names so they look relatively normal

nearby_venues.columns = [col.split(".")[-1] for col in nearby_venues.columns]

nearby_venues
# Out:
#                                  name                        id  \
# 0      Work It Out-A Fitness Boutique  4cdf46dadb125481eb4236ce
# 1                  Church Square Park  49e9e49df964a5200a661fe3
# 2           Onieal's Restaurant & Bar  45e9482df964a52075431fe3
# 3                               Sweet  4a4e740ff964a5207bae1fe3
# 4                           Grand Vin  56d3b920498ec4e1c67c0907
# 5               Hoboken General Store  4b6b0a45f964a520a5ee2be3
# 6                          Karma Kafe  582dfc9565be5809f6a964ed
# 7                             O'Bagel  56daf06fcd107605ef3d86ea
# 8                         Kung Fu Tea  57168865498e9517f09fa03d
# 78         Mexican Restaurant  40.742509 -74.029496
# 79         Italian Restaurant  40.740996 -74.029827
# 80         Italian Restaurant  40.739127 -74.030450
# 81             Sandwich Place  40.742983 -74.029211
# 82               Liquor Store  40.743922 -74.036102
# 83            Thai Restaurant  40.741110 -74.029734
# 84                Yoga Studio  40.738853 -74.032275
# 85               Liquor Store  40.745235 -74.031448
# 86                        Pub  40.746477 -74.032032
# 87                Pizza Place  40.743508 -74.029017
# 88               Concert Hall  40.742485 -74.027692
# 89                    Dog Run  40.741535 -74.028214
# 90               Dessert Shop  40.741697 -74.029651
# 91                  Bookstore  40.742583 -74.029391
# 92         Mexican Restaurant  40.741413 -74.029926
# 93                Pizza Place  40.746364 -74.030152
# 94           Video Game Store  40.741621 -74.029666
# 95                Coffee Shop  40.745082 -74.030464
# 96          Indian Restaurant  40.744077 -74.028975
# 97                        Bar  40.745133 -74.034497
# 98             Cosmetics Shop  40.743232 -74.029175
# 99                   Pharmacy  40.742851 -74.029334

# %%
# find a list of unique categories from the API so we can see what may or may not fit for restaurants

nearby_venues['categories'].unique()
# Out:
# array(['Gym / Fitness Center', 'Park', 'Pub', 'Bakery', 'Cocktail Bar',
#        'Deli / Bodega', 'Indian Restaurant', 'Bagel Shop',
#        'Bubble Tea Shop', "Women's Store", 'Sushi Restaurant',
#        'Falafel Restaurant', 'Sporting Goods Shop', 'American Restaurant',
#        'Coffee Shop', 'Ice Cream Shop', 'Pizza Place', 'Burger Joint',
#        'Optical Shop', 'South American Restaurant', 'Cuban Restaurant',
#        'Seafood Restaurant', 'Gaming Cafe', 'Dog Run', 'Pet Store', 'Bar',
#        'Yoga Studio', 'Shoe Repair', 'Italian Restaurant',
#        'Latin American Restaurant', 'Japanese Restaurant',
#        'Jewelry Store', 'Mexican Restaurant', 'Poke Place',
#        'Sandwich Place', 'Boutique', 'Restaurant', 'Juice Bar',
#        'Cosmetics Shop', 'Record Shop', 'Korean Restaurant',
#        'Business Service', 'Gym', 'Donut Shop', 'Grocery Store',
#        'Sports Bar', 'Stationery Store', 'Dive Bar', 'Thai Restaurant',
#        'Salon / Barbershop', 'Pilates Studio', 'Liquor Store',
#        'Concert Hall', 'Dessert Shop', 'Bookstore', 'Video Game Store',
#        'Pharmacy'], dtype=object)

# %%
# creating a list of categorie to remove from our dataframe because they are not restaurants
# I am sure there is a function that can be written to do this at scale but since it was a small list, I did it manually

removal_list = ['Gym / Fitness Center', 'Bakery', 'Park', "Women's Store", 'Sporting Goods Shop', 'Dog Run', 'Gaming Cafe',
               'Optical Shop', 'Yoga Studio', 'Pet Store', 'Shoe Repair', 'Jewelry Store', 'Record Shop', 'Juice Bar', 
               'Cosmetics Shop', 'Business Service', 'Salon / Barbershop', 'Liquor Store', 'Grocery Store', 'Stationery Store',
               'Pilates Studio', 'Dessert Shop', 'Bookstore', 'Concert Hall', 'Video Game Store', 'Pharmacy', 'Mobile Phone Shop',
               'Deli / Bodega']

nearby_venues2 = nearby_venues.copy()


#getting a clear dataframe of just restaurants
nearby_venues2 = nearby_venues2[~nearby_venues2['categories'].isin(removal_list)]
# 80         Italian Restaurant  40.739127 -74.030450
# 81             Sandwich Place  40.742983 -74.029211
# 83            Thai Restaurant  40.741110 -74.029734
# 86                        Pub  40.746477 -74.032032
# 87                Pizza Place  40.743508 -74.029017
# 92         Mexican Restaurant  40.741413 -74.029926
# 93                Pizza Place  40.746364 -74.030152
# 95                Coffee Shop  40.745082 -74.030464
# 96          Indian Restaurant  40.744077 -74.028975
# 97                        Bar  40.745133 -74.034497

# %%
#let's get a list of venues

venue_id_list = nearby_venues2['id'].tolist()
venue_id_list
# Out:
# ['45e9482df964a52075431fe3',
#  '56d3b920498ec4e1c67c0907',
#  '582dfc9565be5809f6a964ed',
#  '56daf06fcd107605ef3d86ea',
#  '57168865498e9517f09fa03d',
#  '4dbc9859f7b1ab37dd636d12',
#  '4d9368407b5ea1437d14c8b8',
#  '4a7eff1cf964a5206ff21fe3',
#  '49f26862f964a520296a1fe3',
#  '49f37b88f964a520a26a1fe3',
#  '58e7ed715f67173549fe6246',
#  '49dfb562f964a52001611fe3',
#  '4ca50f407334236a60ef1258',
#  '53ed3b37498e4151087521a9',
#  '4d4218cd607b6dcb31df08c6',
#  '49e2a407f964a52045621fe3',
#  '4a453f9cf964a520f4a71fe3',
#  '4eb1b6859adfb95b77765bf9',
#  '57f83f7acd10164c2ec1956f',
#  '4cdb36c1958f236a15a7ab03',
#  '4ad12c5ef964a5203ddd20e3',
#  '4a9ac1b1f964a520813220e3',
#  '4c60c4a1de6920a111ed9664',
#  '527f3d1711d2f7f001c656b2',
#  '4c03f2fe39d476b0f5c530a7',
#  '4a9578dff964a520562320e3',
#  '4a7b5b6bf964a520c8ea1fe3',
#  '49ee57f6f964a5204f681fe3',
#  '4ad89c0bf964a520d31221e3',
#  '58c470fd37da1d593431c33a',
#  '4a8da189f964a520501020e3',
#  '4bddbf6be75c0f47f171c503',
#  '55d52901498ea18f871d5f9e',
#  '5a6b6047f427de038c51031c',
#  '56f136ad498ecc5661aa49ce',
#  '5a888bc2c47cf91545daec08',
#  '5131669e582f0b9471213351',
#  '5065c556e4b0a44a76b324ce',
#  '5c40edaaad910e0039b9fc01',
#  '4c41e1aee26920a1981e5fe7',
#  '4b76e28df964a52021672ee3',
#  '5c6ba79f12c8f0002c2bdf71',
#  '4b191a58f964a520ffd723e3',
#  '4a3ad481f964a52057a01fe3',
#  '56c5003ccd10e29c9c30a7f8',
#  '4283ee00f964a52091221fe3',
#  '59fd168ec21cb1401894e47e',
#  '49ce95d4f964a5205f5a1fe3',
#  '49e27ed2f964a5201c621fe3',
#  '49e37784f964a52083621fe3',
#  '4a9c695cf964a520153720e3',
#  '567b01d8498e9310602c8d10',
#  '51070e83e4b0d92d935e04a3',
#  '4acce0aaf964a520d8c920e3',
#  '522cb84211d20c34ef82194f',
#  '4af5d847f964a520aefd21e3',
#  '49eabe84f964a52090661fe3',
#  '4b44d83ef964a520f4fd25e3',
#  '5b5b1e0bd4cc9800394e3256',
#  '5b857f112f97ec002c294c98',
#  '49cf90f2f964a520ae5a1fe3']

# %%
#set up to pull the likes from the API based on venue ID

url_list = []
like_list = []
json_list = []

for i in venue_id_list:
    venue_url = 'https://api.foursquare.com/v2/venues/{}/likes?client_id={}&client_secret={}&v={}'.format(i, CLIENT_ID, CLIENT_SECRET, VERSION)
    url_list.append(venue_url)
for link in url_list:
    result = requests.get(link).json()
    likes = result['response']['likes']['count']
    like_list.append(likes)
print(like_list)
# Out:
# [152, 68, 41, 67, 29, 70, 268, 102, 117, 132, 69, 65, 138, 83, 184, 104, 70, 167, 30, 82, 46, 165, 64, 53, 32, 75, 36, 13, 21, 24, 72, 4, 10, 36, 11, 13, 120, 105, 5, 17, 49, 0, 39, 69, 6, 47, 15, 121, 46, 111, 34, 24, 23, 20, 68, 18, 31, 22, 14, 6, 72]

# %%
#double check that we did not lose any venues based on if likes were available

print(len(like_list))
print(len(venue_id_list))
# Out:
# 61
# 61

# %%
#let's make a copy of our initial dataframe just in case anything goes wrong

hoboken_venues = nearby_venues2.copy()
hoboken_venues.head()
# Out:
#                         name                        id         categories  \
# 2  Onieal's Restaurant & Bar  45e9482df964a52075431fe3                Pub
# 4                  Grand Vin  56d3b920498ec4e1c67c0907       Cocktail Bar
# 6                 Karma Kafe  582dfc9565be5809f6a964ed  Indian Restaurant
# 7                    O'Bagel  56daf06fcd107605ef3d86ea         Bagel Shop
# 8                Kung Fu Tea  57168865498e9517f09fa03d    Bubble Tea Shop
#
#          lat        lng
# 2  40.741608 -74.032304
# 4  40.743209 -74.035099
# 6  40.742373 -74.029376
# 7  40.743603 -74.029173
# 8  40.743347 -74.029379

# %%
# add in the list of likes

hoboken_venues['total likes'] = like_list
hoboken_venues.head()
# Out:
#                         name                        id         categories  \
# 2  Onieal's Restaurant & Bar  45e9482df964a52075431fe3                Pub
# 4                  Grand Vin  56d3b920498ec4e1c67c0907       Cocktail Bar
# 6                 Karma Kafe  582dfc9565be5809f6a964ed  Indian Restaurant
# 7                    O'Bagel  56daf06fcd107605ef3d86ea         Bagel Shop
# 8                Kung Fu Tea  57168865498e9517f09fa03d    Bubble Tea Shop
#
#          lat        lng  total likes
# 2  40.741608 -74.032304          152
# 4  40.743209 -74.035099           68
# 6  40.742373 -74.029376           41
# 7  40.743603 -74.029173           67
# 8  40.743347 -74.029379           29

# %%
# now let's bin total likes

print(hoboken_venues['total likes'].max())
print(hoboken_venues['total likes'].min())
print(hoboken_venues['total likes'].median())
print(hoboken_venues['total likes'].mean())
# Out:
# 268
# 0
# 47.0
# 62.21311475409836

# %%
# let's visualize our total likes based on a histogram

import matplotlib.pyplot as plt
hoboken_venues['total likes'].hist(bins=4)
plt.show()

# %%
# what are the bins we want to use?

print(np.percentile(hoboken_venues['total likes'], 25))
print(np.percentile(hoboken_venues['total likes'], 50))
print(np.percentile(hoboken_venues['total likes'], 75))
# Out:
# 22.0
# 47.0
# 82.0

# %%
# now we have our bin values so let's set them to the appropriate values
# less than 24, 24-45, 45-76, 76>
# poor, below avg, abv avg, great

poor = hoboken_venues['total likes']<=24
below_avg = hoboken_venues[(hoboken_venues['total likes']>24) & (hoboken_venues['total likes']<=45)]
abv_avg = hoboken_venues[(hoboken_venues['total likes']>45) & (hoboken_venues['total likes']<=76)]
great = hoboken_venues['total likes']>76

# %%
# let's set up a function that will re-categorize our restaurants based on likes

def conditions(s):
    if s['total likes']<=24:
        return 'poor'
    if s['total likes']<=45:
        return 'below avg'
    if s['total likes']<=76:
        return 'avg avg'
    if s['total likes']>76:
        return 'great'

hoboken_venues['total likes_cat']=hoboken_venues.apply(conditions, axis=1)

# %%
hoboken_venues
# Out:
#                               name                        id  \
# 2        Onieal's Restaurant & Bar  45e9482df964a52075431fe3
# 4                        Grand Vin  56d3b920498ec4e1c67c0907
# 6                       Karma Kafe  582dfc9565be5809f6a964ed
# 7                          O'Bagel  56daf06fcd107605ef3d86ea
# 8                      Kung Fu Tea  57168865498e9517f09fa03d
# 12           Ayame Hibachi & Sushi  4dbc9859f7b1ab37dd636d12
# 13                Mamoun's Falafel  4d9368407b5ea1437d14c8b8
# 15   Court Street Bar & Restaurant  4a7eff1cf964a5206ff21fe3
# 16     Zack's Oak Bar & Restaurant  49f26862f964a520296a1fe3
# 17             Empire Coffee & Tea  49f37b88f964a520a26a1fe3
# 19                  Bluestone Lane  58e7ed715f67173549fe6246
# 20                   Ben & Jerry's  49dfb562f964a52001611fe3
# 21                      Grimaldi's  4ca50f407334236a60ef1258
# 22                      Bareburger  53ed3b37498e4151087521a9
# 24                   Cork City Pub  4d4218cd607b6dcb31df08c6
# 26                     Cucharamama  49e2a407f964a52045621fe3
# 27                           Zafra  4a453f9cf964a520f4a71fe3
# 28                       The Cuban  4eb1b6859adfb95b77765bf9
# 29                     Tutta Pesca  57f83f7acd10164c2ec1956f
# 30                         Robongi  4cdb36c1958f236a15a7ab03
# 34                     Moran's Pub  4ad12c5ef964a5203ddd20e3
# 35                  Benny Tudino's  4a9ac1b1f964a520813220e3
# 38                         Dozzino  4c60c4a1de6920a111ed9664
# 39                     Otto Strada  527f3d1711d2f7f001c656b2
# 40                    Ultramarinos  4c03f2fe39d476b0f5c530a7
# 41                        Illuzion  4a9578dff964a520562320e3
# 42                  Cafe Michelina  4a7b5b6bf964a520c8ea1fe3
# 44                 Hoboken Burrito  49ee57f6f964a5204f681fe3
# 45                       Mr Wrap's  4ad89c0bf964a520d31221e3
# 46                   Makai Poke Co  58c470fd37da1d593431c33a
# 47             Vito's Italian Deli  4a8da189f964a520501020e3
# 48                Townhouse No 620  4bddbf6be75c0f47f171c503
# 49                 Flatbread Grill  55d52901498ea18f871d5f9e
# 50                Mamoun’s Falafel  5a6b6047f427de038c51031c
# 53              Pita Pit (Hoboken)  56f136ad498ecc5661aa49ce
# 55              Jefferson’s Coffee  5a888bc2c47cf91545daec08
# 56                  The Stewed Cow  5131669e582f0b9471213351
# 57          Chipotle Mexican Grill  5065c556e4b0a44a76b324ce
# 59                        Gong Cha  5c40edaaad910e0039b9fc01
# 61                 Chicken Factory  4c41e1aee26920a1981e5fe7
# 63              Hoboken Hot Bagels  4b76e28df964a52021672ee3
# 64                  Planet Fitness  5c6ba79f12c8f0002c2bdf71
# 57         Mexican Restaurant  40.739599 -74.029981          105
# 59            Bubble Tea Shop  40.743034 -74.029034            5
# 61          Korean Restaurant  40.742975 -74.029083           17
# 63                 Bagel Shop  40.744448 -74.028822           49
# 64                        Gym  40.743673 -74.028801            0
# 65                 Donut Shop  40.744912 -74.028920           39
# 67                 Sports Bar  40.744032 -74.028956           69
# 68                   Boutique  40.740742 -74.030123            6
# 70                   Dive Bar  40.740880 -74.029480           47
# 71                Pizza Place  40.739404 -74.034909           15
# 72                Coffee Shop  40.740723 -74.030130          121
# 73            Thai Restaurant  40.740103 -74.030955           46
# 78         Mexican Restaurant  40.742509 -74.029496          111
# 79         Italian Restaurant  40.740996 -74.029827           34
# 80         Italian Restaurant  40.739127 -74.030450           24
# 81             Sandwich Place  40.742983 -74.029211           23
# 83            Thai Restaurant  40.741110 -74.029734           20
# 86                        Pub  40.746477 -74.032032           68
# 87                Pizza Place  40.743508 -74.029017           18
# 92         Mexican Restaurant  40.741413 -74.029926           31
# 93                Pizza Place  40.746364 -74.030152           22
# 95                Coffee Shop  40.745082 -74.030464           14
# 96          Indian Restaurant  40.744077 -74.028975            6
# 97                        Bar  40.745133 -74.034497           72
#
#    total likes_cat
# 2            great
# 4          avg avg
# 6        below avg
# 7          avg avg
# 8        below avg
# 12         avg avg
# 13           great
# 15           great
# 16           great
# 17           great
# 19         avg avg
# 20         avg avg
# 21           great
# 22           great
# 24           great
# 26           great
# 27         avg avg
# 28           great
# 29       below avg
# 30           great
# 34         avg avg
# 35           great
# 38         avg avg
# 39         avg avg
# 40       below avg
# 41         avg avg
# 42       below avg
# 44            poor
# 45            poor
# 46            poor
# 47         avg avg
# 48            poor
# 49            poor
# 50       below avg
# 53            poor
# 55            poor
# 56           great
# 57           great
# 59            poor
# 61            poor
# 63         avg avg
# 64            poor
# 65       below avg
# 67         avg avg
# 68            poor
# 70         avg avg
# 71            poor
# 72           great
# 73         avg avg
# 78           great
# 79       below avg
# 80            poor
# 81            poor
# 83            poor
# 86         avg avg
# 87            poor
# 92       below avg
# 93            poor
# 95            poor
# 96            poor
# 97         avg avg

# %%
# let's star the process for re-categorizing the categories

hoboken_venues['categories'].unique()
# Out:
# array(['Pub', 'Cocktail Bar', 'Indian Restaurant', 'Bagel Shop',
#        'Bubble Tea Shop', 'Sushi Restaurant', 'Falafel Restaurant',
#        'American Restaurant', 'Coffee Shop', 'Ice Cream Shop',
#        'Pizza Place', 'Burger Joint', 'South American Restaurant',
#        'Cuban Restaurant', 'Seafood Restaurant', 'Bar',
#        'Italian Restaurant', 'Latin American Restaurant',
#        'Japanese Restaurant', 'Mexican Restaurant', 'Poke Place',
#        'Sandwich Place', 'Boutique', 'Restaurant', 'Korean Restaurant',
#        'Gym', 'Donut Shop', 'Sports Bar', 'Dive Bar', 'Thai Restaurant'],
#       dtype=object)

# %%
# let's create our new categories and create a function to apply those to our existing data


bars = ['Pub', 'Cocktail Bar', 'Bar', 'Dive Bar', 'Sports Bar']
other = ['Bagel Shop', 'Tea Room', 'Donut Shop', 'Coffee Shop', 'Bubble Tea Shop', 'Sandwich Place', 'Boutique', 'Ice Cream Shop']
euro_asia_indian_food = ['Falafel Restaurant', 'Korean Restaurant','Sushi Restaurant', 'Indian Restaurant', 'Japanese Restaurant', 'Poke Place', 'Thai Restaurant', 'Vietnamese Restaurant']
mex_southam_food = ['Cuban Restaurant', 'Mexican Restaurant', 'South American Restaurant', 'Latin American Restaurant']
american_food = ['Burger Joint', 'Restaurant', 'American Restaurant']
italian_food = ['Italian Restaurant', 'Seafood Restaurant', 'Pizza Place']

def conditions2(s):
    if s['categories'] in bars:
        return 'bars'
    if s['categories'] in other:
        return 'other'
    if s['categories'] in euro_asia_indian_food:
        return 'euro asia indian food'
    if s['categories'] in mex_southam_food:
        return 'mex southam food'
    if s['categories'] in american_food:
        return 'american food'
    if s['categories'] in italian_food:
        return 'italian food'

hoboken_venues['categories_new']=hoboken_venues.apply(conditions2, axis=1)

# %%
hoboken_venues
# Out:
#                               name                        id  \
# 2        Onieal's Restaurant & Bar  45e9482df964a52075431fe3
# 4                        Grand Vin  56d3b920498ec4e1c67c0907
# 6                       Karma Kafe  582dfc9565be5809f6a964ed
# 7                          O'Bagel  56daf06fcd107605ef3d86ea
# 8                      Kung Fu Tea  57168865498e9517f09fa03d
# 12           Ayame Hibachi & Sushi  4dbc9859f7b1ab37dd636d12
# 13                Mamoun's Falafel  4d9368407b5ea1437d14c8b8
# 15   Court Street Bar & Restaurant  4a7eff1cf964a5206ff21fe3
# 16     Zack's Oak Bar & Restaurant  49f26862f964a520296a1fe3
# 17             Empire Coffee & Tea  49f37b88f964a520a26a1fe3
# 19                  Bluestone Lane  58e7ed715f67173549fe6246
# 20                   Ben & Jerry's  49dfb562f964a52001611fe3
# 21                      Grimaldi's  4ca50f407334236a60ef1258
# 22                      Bareburger  53ed3b37498e4151087521a9
# 24                   Cork City Pub  4d4218cd607b6dcb31df08c6
# 26                     Cucharamama  49e2a407f964a52045621fe3
# 27                           Zafra  4a453f9cf964a520f4a71fe3
# 28                       The Cuban  4eb1b6859adfb95b77765bf9
# 29                     Tutta Pesca  57f83f7acd10164c2ec1956f
# 30                         Robongi  4cdb36c1958f236a15a7ab03
# 34                     Moran's Pub  4ad12c5ef964a5203ddd20e3
# 35                  Benny Tudino's  4a9ac1b1f964a520813220e3
# 38                         Dozzino  4c60c4a1de6920a111ed9664
# 39                     Otto Strada  527f3d1711d2f7f001c656b2
# 40                    Ultramarinos  4c03f2fe39d476b0f5c530a7
# 41                        Illuzion  4a9578dff964a520562320e3
# 42                  Cafe Michelina  4a7b5b6bf964a520c8ea1fe3
# 44                 Hoboken Burrito  49ee57f6f964a5204f681fe3
# 45                       Mr Wrap's  4ad89c0bf964a520d31221e3
# 46                   Makai Poke Co  58c470fd37da1d593431c33a
# 47             Vito's Italian Deli  4a8da189f964a520501020e3
# 48                Townhouse No 620  4bddbf6be75c0f47f171c503
# 49                 Flatbread Grill  55d52901498ea18f871d5f9e
# 50                Mamoun’s Falafel  5a6b6047f427de038c51031c
# 53              Pita Pit (Hoboken)  56f136ad498ecc5661aa49ce
